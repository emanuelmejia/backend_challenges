# %% [markdown]
# # Lab 10

# %% [markdown]
# #### ``Objectives``
# 1. Implement a CNN to detect diabetic retinopathy (DR) from retina images taken using fundus photography under a variety of imaging conditions
# 2. Improve generalization performance and reduce overfitting using **image transformation** and **data augmentation** techniques
# 3. Tune hyperparameters of the CNN model

# %% [markdown]
# #### ``Motivation``

# %% [markdown]
# Diabetic retinopathy (DR) is an eye condition that  affects blood vessels in the retina. It can cause vision loss and blindness in people who have diabetes. Screening for DR allows earlier and more effective treatment options for millions of people.

# %% [markdown]
# #### ``Data``

# %% [markdown]
# In this assignment you will use a small dataset of retina images (`Download` links: [images](https://drive.google.com/drive/folders/1sdfUC64Un1iwuiHEehcbijxB54OhU_nd?usp=sharing) and [labels](https://drive.google.com/drive/folders/1MOlSJBZg7L1HtG5vHPt77ighRvQaGfDg?usp=sharing)). You will **build** and **train** a **CNN model** to predict whether or not to refer a patient for DR treatment using binarized severity of DR in patients: no referral if {No DR, mild} and referral if {moderate, severe, and proliferate DR}.
#
#
# <u>Note</u>: the original dataset is hosted by Kaggle [[Source]](https://www.kaggle.com/c/aptos2019-blindness-detection/).

# %% [markdown]
# Import the necessary libraries and make sure to replace IMAGE_PATH and LABEL_PATH with the path to the directories where you saved the data.

# %%
# standard
import pandas as pd
import numpy as np
import random
import os

# tf and keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras import models
from keras import layers

# plots
import seaborn as sns
import matplotlib.pyplot as plt

random.seed(2)
# %matplotlib inline

# FILL IN CODE HERE #
IMAGE_PATH = '.\Data\CNN_images\\' # replace with your path
LABEL_PATH = '.\Data\\' # replace with your path

# %% [markdown]
# At this point, you may ask yourself what the best CNN model that fits this data is. First, you will want to read through the data description in Kaggle (see the link to the original dataset above). Understanding what you are working with challenges you to write preprocessing code that uncovers your data's most helpful information.

# %% [markdown]
# ---
# ### Exercise 1 (8 points)

# %% [markdown]
# Read the data description from Kaggle and list (a) the source of images and (b) the labeling procedure.

# %% [markdown]
# ### WRITTEN ANSWER
#
# ***a. Source of images:*** This is a set of retina images taken from multiple clinics using a variety of cameras over an extended period of time, using fundus photography under a variety of imaging conditions. Gathered in India by Araving Eye Hospital technicians, who travel to different rural areas to take them and help identify diabetic retinopathy to improve the hospital’s ability to identify potential patients. Images may contain noise in both the images and labels, artifacts, be out of focus, underexposed, or overexposed.
#
# ***b. Labeling procedure:*** Highly trained doctors to review the images and provide diagnosis, each image is rated for the severity of diabetic retinopathy on a scale of 0 to 4:
#
# - 0 - No DR
# - 1 - Mild
# - 2 - Moderate
# - 3 - Severe
# - 4 - Proliferative DR

# %% [markdown]
# ---

# %% [markdown]
# ## Read data

# %% [markdown]
# Let's now explore our dataset. We will start with label inspection and continue with image visualization.

# %%
y = pd.read_csv(
    LABEL_PATH + 'labels.csv'
)

print('Shape of labels:', y.shape)
print('Unique diagnosis codes:', np.sort(y.diagnosis.unique()))
y.head()
# Out:
# Shape of labels: (200, 2)
# Unique diagnosis codes: [0 1 2 3 4]
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  0024cdab0c1e          1
# 2  0083ee8054ee          4
# 3  00a8624548a9          2
# 4  00b74780d31d          2

# %% [markdown]
# There are 200 training images corrresponding to 5 different diabetic retinopathy (DR) diagnosis codes:
#
# * No DR (0)
# * mild (1)
# * moderate (2)
# * severe (3)
# * proliferate DR (4)

# %% [markdown]
# Image inspection:

# %%
# read image
indx=0
images = []

print('Sample of images in data:')
for idx, img in enumerate(os.listdir(IMAGE_PATH)):
    img = load_img(
    IMAGE_PATH + img)
    images.append(img)

nrows, ncols = 2,4 #print first 8 images
f, axs = plt.subplots(nrows, ncols, figsize=(20,10))
for i in range(nrows):
    for j in range(ncols):
        indx = i*nrows+j
        axs[i,j].imshow(images[indx])
# Out:
# Sample of images in data:

# %% [markdown]
# Like any real-world data set, you can see that these images have different sizes and focus. Later, you will use image transformation and data augmentation techniques to remove some of this variation.

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# The quality of the data determines how well a machine learning algorithm can learn. This section will apply some simple techniques to deal with class imbalance. We will then create training/validation/test datasets and perform image transformation and augmentation.

# %% [markdown]
# ---
# ### Exercise 2 (8 points)

# %% [markdown]
# Graph a histogram for the five classes of DR. Write down the percentage of the largest class in the written answer below.

# %%
# YOUR CODE HERE
diag_codes = ['0-No_DR', '1-mild', '2-moderate', '3-severe', '4-proliferate']
diagnoses = y['diagnosis']
diagnoses = diagnoses.replace([0, 1, 2, 3, 4], diag_codes)

diag_df = pd.DataFrame({'count': diagnoses.value_counts()})
diag_df['%'] = diag_df['count'] / len(diagnoses)*100
diag_df = diag_df.sort_index()

ax = plt.axes()
plt.bar(diag_df.index, diag_df['count'], align = 'center')
ax.set_xticks([0,1,2,3,4])
# Spine formatting
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('cornflowerblue')
ax.spines['bottom'].set_color('cornflowerblue')

# Tick formatting
ax.tick_params(axis='y', which='both', length=0, colors = 'gray')
ax.tick_params(axis='x', which='both', color='cornflowerblue', colors = 'gray')

# Grid formatting
ax.grid(False)
vals = ax.get_yticks()
for tick in vals:
    ax.axhline(y=tick, linestyle='dashed', alpha=0.4, color='cornflowerblue', zorder=1)

# Setting text labels according to the count of df
rects = ax.patches
percentages = diag_df['%']
counts = diag_df['count']

for rect, label, cnt in zip(rects, percentages, counts):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height+0.01, str(label) + '%',
            ha='center', va='bottom', color = 'gray',weight='normal')
    height = rect.get_height() + 5
    ax.text(rect.get_x() + rect.get_width() / 2, height+0.01, cnt,
            ha='center', va='bottom', color = 'royalblue',weight='bold')
    
# Set title
ax.set_title("Distribution of Classes", weight='bold', size=20)

# Set x-axis label
ax.set_xlabel("Class", labelpad=20, weight='bold', size=10, color='gray')

# Set y-axis label
ax.set_ylabel("Counts", labelpad=20, weight='bold', size=10, color='gray')

diag_df
# Out:
#                count     %
# 0-No_DR           82  41.0
# 1-mild            18   9.0
# 2-moderate        73  36.5
# 3-severe          12   6.0
# 4-proliferate     15   7.5

# %% [markdown]
# ### WRITTEN ANSWER

# %% [markdown]
# ***2. The class with largest percentage is:***

# %%
diag_df[diag_df['%'] == diag_df['%'].max()]
# Out:
#          count     %
# 0-No_DR     82  41.0

# %% [markdown]
# ---

# %% [markdown]
# `Correct for data imbalance`

# %% [markdown]
# As you can see from the histogram above, our dataset is very imbalanced, which is common in healthcare, and it happens because some diseases are rare. The presence of imbalanced data hampers the detection of rare events as most classification methods implicitly assume a similar occurrence of classes and are designed to maximize the overall classification accuracy.
#
# We will correct for class imbalance in two ways:
#
#   * First, we will binarize the DR diagnosis as follows:
#      - 'no refer' are {No DR, mild}
#      - 'refer' are {Moderate, Severe, Proliferate}
#
#
#   * Second, we'll only take 80 random samples from the 'no refer' class and 80 from the 'refer' class.
#
# It is a crude method to deal with imbalanced data, but it will be good enough for this homework.

# %%
np.random.seed(1234) #1234

no_refer = y[y.diagnosis.isin((0,1))]
refer = y[y.diagnosis.isin((2,3,4))]

# randomly draw 80 images from each classes
temp_no_refer = list(np.random.choice(
    no_refer.id_code,
    size=80,
    replace=False
))

temp_refer = list(np.random.choice(
    refer.id_code,
    size=80,
    replace=False
))

# %% [markdown]
# Next, we will use the **preprocess_data_part1()** function defined below to generate lists of images and labels (`images_mini` and `y_mini`) based on the values in the temp_no_refer and temp_refer lists.

# %%
def preprocess_data_part1(IMAGE_PATH, LABEL_PATH):
    """ Generate lists of images and labelsbased on temp_no_refer and temp_refer lists
    
    Params:
    -------
    IMAGE_PATH (str): path to directory with images.
    LABEL_PATH (str): path to directory with labels.
    
    Returns:
    --------
    images_mini  (np.ndarray): Images of shape (N, 224, 224, 3)
    y_mini (np.ndarray): Labels of shape (N,)    
    """
    y_mini = []
    images_mini = []

    # create lists of images and labels `images_mini` and `y_mini` 
    # based on temp_no_refer and temp_refer selections
    for idx, img in enumerate(os.listdir(IMAGE_PATH)):
        # read labels
        if img.split('.')[0] in temp_no_refer:
                y_mini.append(0)
        elif img.split('.')[0] in temp_refer:
                y_mini.append(1)
        else:
            continue

        
        # read image
        img = load_img(
            IMAGE_PATH + img,
            target_size=(224, 224)
        )
        
        # transform image to array
        img = img_to_array(img)

        # append to images
        images_mini.append(img)

    # stack images and trasnform to array
    images_mini = np.stack(images_mini)
    y_mini = np.array(y_mini).flatten() 
    
    return images_mini, y_mini

# %%
# generate images and labels based on preprocess_data_part1() function
images_mini, y_mini = preprocess_data_part1(IMAGE_PATH, LABEL_PATH)

print(f"images_mini shape {images_mini.shape}")
print(f"y_mini shape {y_mini.shape}")
# Out:
# images_mini shape (160, 224, 224, 3)
# y_mini shape (160,)

# %% [markdown]
# `Create train/validation/test data` and ``perform image tranformation and augmentation``

# %% [markdown]
# The next step in the data preprocessing part is to split the data into training, validation, and test sets. Once we have these partitions, we will apply image transformation and augmentations.
#
#
# To give you an idea of what image transformation and augmentation do, let's see an example applied to the first image in our mini data.

# %%
tf.random.set_seed(1234)

fig = plt.figure(figsize=(14, 12))

# pull first image from data
image = images_mini[0]

# plot original
ax = fig.add_subplot(1, 5, 1)
ax.imshow(array_to_img(image))
ax.set_title('Original', size=15);

# resize
ax = fig.add_subplot(1, 5, 2)
img_resize = tf.image.resize(image, size=(224, 224))
ax.imshow(array_to_img(img_resize))
ax.set_title('Step 1: Resize', size=15);


# adjust brightness
ax = fig.add_subplot(1, 5, 3)
img_bright = tf.image.adjust_brightness(img_resize, 0.3)
ax.imshow(array_to_img(img_bright))
ax.set_title('Step 2: Brightness', size=15);


# adjust contrast
ax = fig.add_subplot(1, 5, 4)
img_contrast = tf.image.adjust_contrast(img_bright, contrast_factor=3)
ax.imshow(array_to_img(img_contrast))
ax.set_title('Step 3: Contrast', size=15);


# flip left right
ax = fig.add_subplot(1, 5, 5)
img_flip = tf.image.flip_left_right(img_contrast)
ax.imshow(array_to_img(img_flip))
ax.set_title('Step 4: Flip left right', size=15);

# %% [markdown]
# Next, we will define and run the **preprocess_data_part2()** function to create:
#
# * train/validation/test sets with split (0.6,0.2,0.2)
#
# * image transformation and augmentation, as follows:
#
# <u>Applied on training, validation and test sets</u>:
#   - resize to IMAGE_SIZE =(224,224) using tf.image.resize()
#   - normalize all pixel values to the range (0,1)
#
# <u>Applied on training set only</u> (note that this step will create additional/augmented copies of the training data):
#   - adjust brightness by adding DELTA=0.3 to the pixel values using tf.image.adjust_brighness()
#   - adjust contrast to CONTRAST_FACTOR=3 using tf.image.adjust_contrast()
#   - flip left right using tf.image.flip_left_right()

# %% [markdown]
# The quantity and diversity of data gathered have a significant impact on the results of a CNN model. One can apply augmentations to artificially inflate the training dataset by warping the original data such that their label does not change. These augmentations can significantly improve learning results without collecting new data.

# %%
# Decided to put these inside the function
# So I can change them in the last exercise

# IMAGE_SIZE = (224, 224)
# CONTRAST_FACTOR = 3
# DELTA = 0.3

def preprocess_data_part2(images, y, split=(0.6,0.2,0.2),
                          IMAGE_SIZE = (224, 224),
                          CONTRAST_FACTOR = 3,
                          DELTA = 0.3, 
                          flip = 'yes'):
    """ Split data into train, validation and test sets; apply transformaions and augmentations
    
    Params:
    -------
    images  (np.ndarray): Images of shape (N, 224, 224, 3)
    y (np.ndarray): Labels of shape (N,)   
    split (tuple): 3 values summing to 1 defining split of train, validation and test sets
    
    Returns:
    --------
    X_train (np.ndarray): Train images of shape (N_train, 224, 224, 3)
    y_train (np.ndarray): Train labels of shape (N_train,)
    X_val (np.ndarray): Val images of shape (N_val, 224, 224, 3)
    y_val (np.ndarray): Val labels of shape (N_val,)
    X_test (np.ndarray): Test images of shape (N_test, 224, 224, 3)
    y_test (np.ndarray): Test labels of shape (N_test,)
    
    """
    
    ### create train/validation/test sets ###
    #########################################
    # NOTE: Each time you run this cell, you'll re-shuffle the data. The ordering will be the same due to the random seed generator 
    tf.random.set_seed(1234)
    np.random.seed(1234)
    shuffle = np.random.permutation(np.arange(images.shape[0]))
    images, y = images[shuffle], y[shuffle]
    
    splits = np.multiply(len(images_mini), split).astype(int)
    X_train, X_val, X_test = np.split(images_mini, [splits[0], splits[0]+splits[1]])
    y_train, y_val, y_test = np.split(y_mini, [splits[0], splits[0]+splits[1]])
    
    ### image transformation on training, validation, and test data ###
    ###################################################################
    # image resize
    X_train = tf.image.resize(X_train, size=IMAGE_SIZE)
    X_val = tf.image.resize(X_val, size=IMAGE_SIZE)
    X_test = tf.image.resize(X_test, size=IMAGE_SIZE)
    
    # rescale image to [0,1], i.e., greyscale
    X_train = X_train/255.0
    X_val = X_val/255.0
    X_test = X_test/255.0
    
    
    ### image augmentation on training data ###
    ###########################################
    # adjust brightness
    X_train_augm = tf.image.adjust_brightness(X_train, delta=DELTA)
    
    # adjust contrast
    X_train_augm = tf.image.adjust_contrast(X_train_augm, contrast_factor=CONTRAST_FACTOR)

    # random flip
    if flip == 'yes':
        X_train_augm = tf.image.random_flip_left_right(X_train_augm)
    
    # concatenate original X_train and augmented X_train data
    X_train = tf.concat([X_train, X_train_augm],axis=0)
    
    # concatenate y_train (note the label is preserved)
    y_train_augm = y_train
    y_train = tf.concat([y_train, y_train_augm],axis=0)
    
    # shuffle X_train and y_train, i.e., shuffle two tensors in the same order
    shuffle = tf.random.shuffle(tf.range(tf.shape(X_train)[0], dtype=tf.int32))
    X_train = tf.gather(X_train, shuffle)
    y_train = tf.gather(y_train, shuffle).numpy() #also transforms y_train to numpy array
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# Let's sanity check our implementation of the preprocess_data_part2() function by printing the shape of (X,y) from train, validation and test sets.

# %%
X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data_part2(
    images_mini,
    y_mini,
    split=(0.6,0.2,0.2)
)

print(f"X_train shape {X_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_val shape {X_val.shape}")
print(f"y_val shape {y_val.shape}")
print(f"X_test shape {X_test.shape}")
print(f"y_test shape {y_test.shape}")
# Out:
# X_train shape (192, 224, 224, 3)
# y_train shape (192,)
# X_val shape (32, 224, 224, 3)
# y_val shape (32,)
# X_test shape (32, 224, 224, 3)
# y_test shape (32,)

# %% [markdown]
# Let's also print out the first 8 train and validation examples with the label of each example as the title.

# %%
# print taining data
print('Print training data examples:')
nrows, ncols = 1,4 #print first 4 images
f, axs = plt.subplots(nrows, ncols, figsize=(14,12))
for i in range(ncols):
    axs[i].imshow(array_to_img(X_train[i]))
    axs[i].set(title=y_train[i])
# Out:
# Print training data examples:

# %%
# print test data
print('Print validation data examples:')
nrows, ncols = 1,4 #print first 4 images
f, axs = plt.subplots(nrows, ncols, figsize=(14,12))
for i in range(ncols):
    axs[i].imshow(array_to_img(X_val[i]))
    axs[i].set(title=y_val[i])
# Out:
# Print validation data examples:

# %% [markdown]
# ---
# ### Exercise 3 (8 points)
#
# We've split the data into train, validation, and test sets. Explain the purpose of each of these.

# %% [markdown]
# ### WRITTEN ANSWER

# %% [markdown]
# ***3.a. Training Dataset:*** The actual dataset that we use to train the model. The model *sees* and *learns* from this data.
#
# ***3.b. Validation Dataset:*** The validation set is used to provide an unbiased evaluation of a given model, but this is for frequent evaluation. We may use this data to fine-tune the model hyperparameters. Hence the model occasionally *sees* this data, but it *never learns* from this. We use the validation set results, and update higher level hyperparameters. So the validation set affects a model, but only indirectly.
#
# ***3.c. Testing Dataset:*** The sample of data used to provide an unbiased evaluation of a final model fit on the training dataset. Hence, the model *never learns* from it, and only *sees it after it is completely trained* (using the train and validation sets)

# %% [markdown]
# ___

# %% [markdown]
# ## Model

# %% [markdown]
# Our objective is to build and train a CNN model to refer patients to doctors based on the severity of DR seen in these images. We are interested in exploring binary classification of 'no refer' and 'refer'.
#
# <u>The architecture of our CNN model is as follows</u>:
#
# 1. the model receives input images of size 224 x 224 x 3 (the images have three color channels)
# 2. the input data goes through two convolutional layers that have kernels of size 5 x 5
# 3. the first convolution has 32 output feature maps, and the second one has 64
# 4. each convolution layer is followed by a max-pooling layer (this will reduce the size of the feature maps)
# 5. the last two layers of the model are fully connected with a droput layer in between
#
# For each convolution we use strides=(1,1) to preserve the dimension of the inputs in the resulting feature maps. For the pooling layers, we set strides=(2,2) to subsample the image and shrink the size of the output feature maps. For the dropout layer, we set the probability of dropping input units during training to 0.5.
#
#
# We will implement this architecture using TensorFlow Keras API.

# %% [markdown]
# ``Build model``

# %%
model = tf.keras.Sequential()

# add first convolution layer to the model
model.add(tf.keras.layers.Conv2D(
    filters=32,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='same',
    data_format='channels_last',
    name='conv_1',
    activation='relu'))


# add a max pooling layer with pool size (2,2) and strides of 2
# (this will reduce the spatial dimensions by half)
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2),
    name='pool_1'))


# add second convolutional layer
model.add(tf.keras.layers.Conv2D(
    filters=64,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='same',
    name='conv_2',
    activation='relu'))

# add second max pooling layer with pool size (2,2) and strides of 2
# (this will further reduce the spatial dimensions by half)
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2), name='pool_2')
)


# add a fully connected layer (need to flatten the output of the previous layers first)
model.add(tf.keras.layers.Flatten()) 
model.add(tf.keras.layers.Dense(
    units=1024,
    name='fc_1', 
    activation='relu'))

# add dropout layer
model.add(tf.keras.layers.Dropout(
    rate=0.5))

# add the last fully connected layer
# this last layer sets the activation function to "None" in order to output the logits 
# note that passing activation = "sigmoid" will return class memembership probabilities but
# in TensorFlow logits are prefered for numerical stability
# set units=1 to get a single output unit (remember it's a binary classification problem)
model.add(tf.keras.layers.Dense(
    units=1,
    name='fc_2',
    activation=None))


# build model and print summary
tf.random.set_seed(1)
model.build(input_shape=(None, 224, 224, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 112, 112, 32)      0
#
#  conv_2 (Conv2D)             (None, 112, 112, 64)      51264
#
#  pool_2 (MaxPooling2D)       (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  fc_1 (Dense)                (None, 1024)              205521920
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 205,576,641
# Trainable params: 205,576,641
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ``Compile model``

# %% [markdown]
# The next step is to compile the model. We have to decide on the type of optimizer, loss function, and metrics to compute.
#
# We will use the Adam optimizer for this assignment, the most popular gradient-based optimization algorithm. There are a few other choices, and you can read more [here](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers). The loss (cost) function suitable for our binary classification model is [binary_crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses). We will compute model accuracy on the training, validation and test datasets.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), #set from_ligits=True because our last layer does not apply sigmoid
              metrics=['accuracy'])

# %% [markdown]
# ``Fit model``

# %% [markdown]
# Finally, we will fit the model with 10 epochs on the train set and validate on the validation set. The performance depends on the current starter hyperparameters such as learning rate and choice of optimizer.

# %%
# set random seed to get reproductible results 
# neural network algorithms are stochastic (e.g., due to random weight initialization); setting a random seed helps to get more stable results after each run
# however, best way to deal with randomness is to repeat your experiment many times (30+) and use statistics to summarize the performance of the model
tf.random.set_seed(1234)
np.random.seed(1234)
history = model.fit(X_train, y_train,
                    epochs=10, 
                    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 19s 3s/step - loss: 7.3625 - accuracy: 0.4792 - val_loss: 0.9273 - val_accuracy: 0.5312
# Epoch 2/10
# 6/6 [==============================] - 18s 3s/step - loss: 0.5301 - accuracy: 0.7344 - val_loss: 0.3336 - val_accuracy: 0.7500
# Epoch 3/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.4415 - accuracy: 0.7865 - val_loss: 0.3983 - val_accuracy: 0.6875
# Epoch 4/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3907 - accuracy: 0.7917 - val_loss: 0.3419 - val_accuracy: 0.6875
# Epoch 5/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3586 - accuracy: 0.8021 - val_loss: 0.2840 - val_accuracy: 0.7188
# Epoch 6/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3429 - accuracy: 0.8177 - val_loss: 0.2981 - val_accuracy: 0.7188
# Epoch 7/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3214 - accuracy: 0.8281 - val_loss: 0.3132 - val_accuracy: 0.6875
# Epoch 8/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.2907 - accuracy: 0.8438 - val_loss: 0.2670 - val_accuracy: 0.8125
# Epoch 9/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.2724 - accuracy: 0.8594 - val_loss: 0.3249 - val_accuracy: 0.6875
# Epoch 10/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.2330 - accuracy: 0.8490 - val_loss: 0.3145 - val_accuracy: 0.6562

# %% [markdown]
# Next let's plot loss and accuracy for training and validation sets

# %%
hist = history.history
x_arr = np.arange(len(hist['loss'])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
ax.plot(x_arr, hist['val_loss'], '--<', label='Validation loss')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Loss', size=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist['accuracy'], '-o', label='Train acc.')
ax.plot(x_arr, hist['val_accuracy'], '--<', label='Validation acc.')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Accuracy', size=15)
plt.show()

# %% [markdown]
# ## Show what the CNN model is learning after each layer

# %% [markdown]
# We will pick one example from our training data to visualize our CNN model's learning after each layer. Below we print the original image.

# %%
img_tensor = np.expand_dims(X_train[2], axis = 0);

# Print image tensor shape
print('Shape of image:', img_tensor.shape);
  
# Print image
plt.imshow(img_tensor[0]);
plt.title('label:' + str(y_train[1]))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Shape of image: (1, 224, 224, 3)

# %% [markdown]
# Next we print what the model learns after each layer-channel. It's important to pay attention to the shape of the output image to understand what each layer does to the original input.

# %%
# outputs of the first 4 layers, which include conv2D and max pooling layers
layer_outputs = [layer.output for layer in model.layers[:4]]
activation_model = models.Model(inputs = model.input, outputs = layer_outputs)
activations = activation_model.predict(img_tensor)

# grab layer names
layer_names = []
for layer in model.layers[:4]:
    layer_names.append(layer.name)

# getting activations of each layer
for idx, layer in enumerate(activations):
    if idx in (0,1,2,3):
        print('----------------')
        print('Geeting activations of layer',  idx+1, ':', layer_names[idx])
        activation = layer

        # shape of layer activation
        print('Images size is', activation.shape[1], 'x', activation.shape[2])
        print('Number of channels is', activation.shape[3])

        # print channels
        print('Printing channels:')
        
        # define nrows and ncols depending on number of channels
        if idx in (0,1):
            nrows, ncols = 4,8
        if idx in (2,3):
            nrows, ncols = 8,8

        # plots
        channel=0
        if idx in (0,1):
            f, axs = plt.subplots(nrows, ncols, figsize=(14,12))
        if idx in (2,3):
            f, axs = plt.subplots(nrows, ncols, figsize=(14,20))
            
        for i in range(nrows):
            for j in range(ncols):
                if i==0 and j==0:
                    channel=0
                else:
                    channel+=1

                axs[i,j].matshow(activation[0,:, :, channel], cmap ='viridis')
                axs[i,j].set(title=str(channel))
                #axs[i,j].axis('off') # pay attention to the range of x and y axis
        plt.show()
# Out:
# 1/1 [==============================] - 0s 89ms/step
# ----------------
# Geeting activations of layer 1 : conv_1
# Images size is 224 x 224
# Number of channels is 32
# Printing channels:
# ----------------
# Geeting activations of layer 2 : pool_1
# Images size is 112 x 112
# Number of channels is 32
# Printing channels:
# ----------------
# Geeting activations of layer 3 : conv_2
# Images size is 112 x 112
# Number of channels is 64
# Printing channels:
# ----------------
# Geeting activations of layer 4 : pool_2
# Images size is 56 x 56
# Number of channels is 64
# Printing channels:

# %% [markdown]
# As you can see, initial layers are more interpretable and retain the majority of the features in the input image. As the level of the layer increases, features become less interpretable, they become more abstract and they identify features specific to the class leaving behind the general features of the image.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Evaluation is one of the most important parts of machine learning as it helps us determine how good our trained model is in predicting unseen data.
#
# Notice that (`X_test`, and `y_test`) were not used in the training part. It would be very bad practice to evaluate the model on the test set, and then return and update the model based on those results (then the test set is acting like just another validation set).

# %% [markdown]
# We will now use our test data to evaluate the performance (accuracy) of our CNN model on unseen data. Note that accuracy is the default metric if one compiles the model with the accuracy metric.

# %%
test_results = model.evaluate(X_test, y_test)
print('\nTest Acc. {:.2f}%'.format(test_results[1]*100))
# Out:
# 1/1 [==============================] - 0s 387ms/step - loss: 0.3338 - accuracy: 0.9062
#
# Test Acc. 90.62%

# %% [markdown]
# `get predictions results in the form of class-membership probabilities`

# %% [markdown]
# In the following figure, you can see all the images in the test data along with their ground truth (GT) labels and the predicted probabiliy that they belong to class 1, 'Refer'

# %%
# transform logits to probabilities
pred_logits = model.predict(X_test)
probas = tf.sigmoid(pred_logits)
probas = probas.numpy().flatten()*100
# Out:
# 1/1 [==============================] - 0s 447ms/step

# %%
# plot test data and associated predicred
fig = plt.figure(figsize=(20, 20))

for j, example in enumerate(X_test):
    ax = fig.add_subplot(8,4, j+1)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(array_to_img(example))
    if y_test[j]==0:
        label='no refer'
    else:
        label='refer'
    
    ax.text(
        0.5, -0.15, 
        'GT: {:s}\nPr(refer)={:.0f}%'.format(label, probas[j]), 
        size=16, 
        color='grey',
        horizontalalignment='center',
        verticalalignment='center', 
        transform=ax.transAxes)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Exercise 4 (8 points)

# %% [markdown]
# In this exercise, your task is to experiment with different hyperparameter values to see how sensitive the accuracy of our CNN model is.  In the table below, you will fill in `training and validation accuracy` results corresponding to the last epoch of the model fit.
#
# You will change one hyperparameter value at a time, as follows:
#
# * kernel size = 3 x 3
# * strides = 2 x 2
# * pool size = 3 x 3
# * learning rate = 0.01
# * optimizer = 'SGD'
# * image augmentation applied on the training data: (brightness (delta) = 0.1, contrast = 2, flip = no)
#
# Finally, comment on the CNN model specification that you are most satisfied with based on the accuracy achieved on the training and validation sets. For this specification, what is the accuracy of the test dataset?

# %%
# Generating a Dataframe with all the experiments' information

exp_ind = ['Experiment_' + str(i) for i in range(1,10)]
kern_sz = [(5,5)] + [(3,3)] + [(5,5)] * 7
strides = [(1,1)] * 2 + [(2,2)] + [(1,1)] * 6
pool_sz = [(2,2)] * 3 + [(3,3)] + [(2,2)] * 5
lear_rt = [0.001] * 4 + [0.01] + [0.001] * 4
optimiz = ['Adam'] * 5 + ['SGD'] + ['Adam'] * 3
brgh_dl = [0.3] * 6 + [0.1] + [0.3] * 2
contr_f = [3] * 7 + [2] + [3]
flip_on = ['yes'] * 8 + ['no']

experiments_df = pd.DataFrame({'kernel size': kern_sz, 
                               'strides': strides, 
                               'pool size': pool_sz, 
                               'learning rate': lear_rt, 
                               'optimizer': optimiz, 
                               'brightness (delta)': brgh_dl, 
                               'contrast factor': contr_f, 
                               'flip on train': flip_on},
                             index = exp_ind)

# %%
def build_run_model(kern_sz = (5,5), 
                stri_sz = (1,1), 
                pool_sz = (2,2),
                lear_rt = 0.001, 
                optimiz = 'Adam', 
                brgh_dl = 0.3, 
                contr_f = 3, 
                flip_on = 'yes'):
    
#     images_mini, y_mini = preprocess_data_part1(IMAGE_PATH, LABEL_PATH)
    X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data_part2(
        images_mini,
        y_mini,
        split=(0.6,0.2,0.2),
        CONTRAST_FACTOR = contr_f,
        DELTA = brgh_dl,
        flip = flip_on
    )

    tf.keras.backend.clear_session()
    np.random.seed(1234)
    tf.random.set_seed(1234)
    model = tf.keras.Sequential()

    # add first convolution layer to the model
    model.add(tf.keras.layers.Conv2D(
        filters = 32,
        kernel_size = kern_sz,
        strides = stri_sz,
        padding = 'same',
        data_format = 'channels_last',
        name = 'conv_1',
        activation = 'relu'))


    # add a max pooling layer with pool size (2,2) and strides of 2
    # (this will reduce the spatial dimensions by half)
    model.add(tf.keras.layers.MaxPool2D(
        pool_size = pool_sz,
        name = 'pool_1'))


    # add second convolutional layer
    model.add(tf.keras.layers.Conv2D(
        filters = 64,
        kernel_size = kern_sz,
        strides = stri_sz,
        padding = 'same',
        name = 'conv_2',
        activation = 'relu'))

    # add second max pooling layer with pool size (2,2) and strides of 2
    # (this will further reduce the spatial dimensions by half)
    model.add(tf.keras.layers.MaxPool2D(
        pool_size = pool_sz, 
        name='pool_2'))


    # add a fully connected layer (need to flatten the output of the previous layers first)
    model.add(tf.keras.layers.Flatten()) 
    model.add(tf.keras.layers.Dense(
        units = 1024,
        name = 'fc_1', 
        activation = 'relu'))

    # add dropout layer
    model.add(tf.keras.layers.Dropout(
        rate = 0.5))

    # add the last fully connected layer
    # this last layer sets the activation function to "None" in order to output the logits 
    # note that passing activation = "sigmoid" will return class memembership probabilities but
    # in TensorFlow logits are prefered for numerical stability
    # set units=1 to get a single output unit (remember it's a binary classification problem)
    model.add(tf.keras.layers.Dense(
        units=1,
        name='fc_2',
        activation=None))


    # build model and print summary
    model.build(input_shape=(None, 224, 224, 3))
    
    if optimiz == 'SGD':
        opt = tf.keras.optimizers.SGD(learning_rate = lear_rt)
    elif optimiz == 'Adam':
        opt = tf.keras.optimizers.Adam(learning_rate = lear_rt)
    else:
        opt = optimiz
        print('Optimizer: ' + optimizer)
        
    model.compile(optimizer=opt,
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), #set from_ligits=True because our last layer does not apply sigmoid
              metrics=['accuracy']) 

    history = model.fit(X_train, y_train,
                        epochs=10, 
                        validation_data=(X_val, y_val)
    )
    
    history = pd.DataFrame(history.history)
    test_results = model.evaluate(X_test, y_test)
    
    return history['accuracy'][9], history['val_accuracy'][9], test_results[1]*100

# %%
for i in range (1,10):
    print('Experiment_' + str(i) + '\n')
    print(experiments_df.loc['Experiment_'+ str(i),'kernel size':'flip on train'], '\n')
    
    train_acc, val_acc, test_acc = build_run_model(kern_sz = experiments_df.loc['Experiment_' + str(i), 'kernel size'], 
                                         stri_sz = experiments_df.loc['Experiment_' + str(i), 'strides'],
                                         pool_sz = experiments_df.loc['Experiment_' + str(i), 'pool size'],
                                         lear_rt = experiments_df.loc['Experiment_' + str(i), 'learning rate'],
                                         optimiz = experiments_df.loc['Experiment_' + str(i), 'optimizer'],
                                         brgh_dl = experiments_df.loc['Experiment_' + str(i), 'brightness (delta)'],
                                         contr_f = experiments_df.loc['Experiment_' + str(i), 'contrast factor'],
                                         flip_on = experiments_df.loc['Experiment_' + str(i), 'flip on train'])
    
    experiments_df.loc['Experiment_' + str(i), 'Training accuracy'] = train_acc
    experiments_df.loc['Experiment_' + str(i), 'Validation accuracy'] = val_acc
    experiments_df.loc['Experiment_' + str(i), 'Test accuracy'] = test_acc
    
    print('\n\n')
# Out:
# Experiment_1
#
# kernel size           (5, 5)
# strides               (1, 1)
# pool size             (2, 2)
# learning rate          0.001
# optimizer               Adam
# brightness (delta)       0.3
# contrast factor            3
# flip on train            yes
# Name: Experiment_1, dtype: object
#
# Epoch 1/10
# 6/6 [==============================] - 17s 3s/step - loss: 6.0008 - accuracy: 0.6198 - val_loss: 0.5925 - val_accuracy: 0.7500
# Epoch 2/10
# 6/6 [==============================] - 17s 3s/step - loss: 1.5671 - accuracy: 0.6615 - val_loss: 0.4104 - val_accuracy: 0.6875
# Epoch 3/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.4895 - accuracy: 0.7448 - val_loss: 0.3480 - val_accuracy: 0.6875
# Epoch 4/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.3940 - accuracy: 0.8021 - val_loss: 0.3989 - val_accuracy: 0.6875
# Epoch 5/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.3723 - accuracy: 0.8125 - val_loss: 0.3149 - val_accuracy: 0.6875
# Epoch 6/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.3192 - accuracy: 0.8542 - val_loss: 0.3375 - val_accuracy: 0.6875
# Epoch 7/10
# 6/6 [==============================] - 19s 3s/step - loss: 0.3049 - accuracy: 0.8594 - val_loss: 0.3563 - val_accuracy: 0.6875
# Epoch 8/10
# 6/6 [==============================] - 18s 3s/step - loss: 0.2587 - accuracy: 0.8698 - val_loss: 0.2879 - val_accuracy: 0.7188
# Epoch 9/10
# 6/6 [==============================] - 18s 3s/step - loss: 0.2275 - accuracy: 0.8958 - val_loss: 0.3082 - val_accuracy: 0.6875
# Epoch 10/10
# 6/6 [==============================] - 18s 3s/step - loss: 0.1706 - accuracy: 0.9375 - val_loss: 0.3514 - val_accuracy: 0.7500
# 1/1 [==============================] - 0s 477ms/step - loss: 0.3274 - accuracy: 0.8750
#
#
#
# Experiment_2
#
# kernel size           (3, 3)
# strides               (1, 1)
# pool size             (2, 2)
# learning rate          0.001
# optimizer               Adam
# brightness (delta)       0.3
# contrast factor            3
# flip on train            yes
# Name: Experiment_2, dtype: object
#
# Epoch 1/10
# 6/6 [==============================] - 17s 3s/step - loss: 11.8540 - accuracy: 0.5938 - val_loss: 4.7489 - val_accuracy: 0.4688
# Epoch 2/10
# 6/6 [==============================] - 15s 2s/step - loss: 3.8003 - accuracy: 0.6354 - val_loss: 0.3505 - val_accuracy: 0.8438
# Epoch 3/10
# 6/6 [==============================] - 15s 3s/step - loss: 0.6332 - accuracy: 0.7656 - val_loss: 0.5444 - val_accuracy: 0.5312
# Epoch 4/10
# 6/6 [==============================] - 14s 2s/step - loss: 0.4061 - accuracy: 0.7656 - val_loss: 0.3385 - val_accuracy: 0.7812
# Epoch 5/10
# 6/6 [==============================] - 14s 2s/step - loss: 0.3892 - accuracy: 0.8177 - val_loss: 0.3355 - val_accuracy: 0.7812
# Epoch 6/10
# 6/6 [==============================] - 14s 2s/step - loss: 0.3223 - accuracy: 0.8594 - val_loss: 0.4530 - val_accuracy: 0.6875
# Epoch 7/10
# 6/6 [==============================] - 14s 2s/step - loss: 0.3372 - accuracy: 0.8333 - val_loss: 0.3609 - val_accuracy: 0.6875
# Epoch 8/10
# 6/6 [==============================] - 14s 2s/step - loss: 0.2888 - accuracy: 0.8385 - val_loss: 0.2831 - val_accuracy: 0.7188
# Epoch 9/10
# 6/6 [==============================] - 14s 2s/step - loss: 0.2409 - accuracy: 0.8802 - val_loss: 0.2734 - val_accuracy: 0.7812
# Epoch 10/10
# 6/6 [==============================] - 14s 2s/step - loss: 0.1745 - accuracy: 0.9375 - val_loss: 0.4437 - val_accuracy: 0.7500
# 1/1 [==============================] - 0s 275ms/step - loss: 0.3384 - accuracy: 0.9062
#
#
#
# Experiment_3
#
# kernel size           (5, 5)
# strides               (2, 2)
# pool size             (2, 2)
# learning rate          0.001
# optimizer               Adam
# brightness (delta)       0.3
# contrast factor            3
# flip on train            yes
# Name: Experiment_3, dtype: object
#
# Epoch 1/10
# 6/6 [==============================] - 2s 304ms/step - loss: 0.7558 - accuracy: 0.6510 - val_loss: 0.6777 - val_accuracy: 0.4688
# Epoch 2/10
# 6/6 [==============================] - 2s 260ms/step - loss: 0.5633 - accuracy: 0.6354 - val_loss: 0.5093 - val_accuracy: 0.5938
# Epoch 3/10
# 6/6 [==============================] - 2s 268ms/step - loss: 0.4876 - accuracy: 0.7240 - val_loss: 0.4310 - val_accuracy: 0.6875
# Epoch 4/10
# 6/6 [==============================] - 2s 279ms/step - loss: 0.4265 - accuracy: 0.8073 - val_loss: 0.4274 - val_accuracy: 0.6875
# Epoch 5/10
# 6/6 [==============================] - 2s 267ms/step - loss: 0.3991 - accuracy: 0.8021 - val_loss: 0.3413 - val_accuracy: 0.7812
# Epoch 6/10
# 6/6 [==============================] - 2s 258ms/step - loss: 0.3562 - accuracy: 0.8385 - val_loss: 0.4052 - val_accuracy: 0.6875
# Epoch 7/10
# 6/6 [==============================] - 2s 319ms/step - loss: 0.3156 - accuracy: 0.8490 - val_loss: 0.3095 - val_accuracy: 0.7188
# Epoch 8/10
# 6/6 [==============================] - 2s 263ms/step - loss: 0.2706 - accuracy: 0.9010 - val_loss: 0.2573 - val_accuracy: 0.8750
# Epoch 9/10
# 6/6 [==============================] - 2s 263ms/step - loss: 0.2541 - accuracy: 0.8750 - val_loss: 0.3087 - val_accuracy: 0.7188
# Epoch 10/10
# 6/6 [==============================] - 2s 304ms/step - loss: 0.2189 - accuracy: 0.9219 - val_loss: 0.4076 - val_accuracy: 0.6875
# 1/1 [==============================] - 0s 79ms/step - loss: 0.2894 - accuracy: 0.9062
#
#
#
# Experiment_4
#
# kernel size           (5, 5)
# strides               (1, 1)
# pool size             (3, 3)
# learning rate          0.001
# optimizer               Adam
# brightness (delta)       0.3
# contrast factor            3
# flip on train            yes
# Name: Experiment_4, dtype: object
#
# Epoch 1/10
# 6/6 [==============================] - 8s 1s/step - loss: 1.3353 - accuracy: 0.6302 - val_loss: 0.5167 - val_accuracy: 0.6875
# Epoch 2/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.5219 - accuracy: 0.7292 - val_loss: 0.4451 - val_accuracy: 0.6875
# Epoch 3/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.4702 - accuracy: 0.7656 - val_loss: 0.4069 - val_accuracy: 0.6875
# Epoch 4/10
# 6/6 [==============================] - 6s 1s/step - loss: 0.4212 - accuracy: 0.7812 - val_loss: 0.4760 - val_accuracy: 0.6875
# Epoch 5/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.4586 - accuracy: 0.8073 - val_loss: 0.3290 - val_accuracy: 0.7500
# Epoch 6/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.3793 - accuracy: 0.8125 - val_loss: 0.3477 - val_accuracy: 0.6875
# Epoch 7/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.3621 - accuracy: 0.8333 - val_loss: 0.3600 - val_accuracy: 0.6875
# Epoch 8/10
# 6/6 [==============================] - 6s 1s/step - loss: 0.3689 - accuracy: 0.8229 - val_loss: 0.2940 - val_accuracy: 0.6875
# Epoch 9/10
# 6/6 [==============================] - 6s 1s/step - loss: 0.3600 - accuracy: 0.7917 - val_loss: 0.2981 - val_accuracy: 0.6562
# Epoch 10/10
# 6/6 [==============================] - 7s 1s/step - loss: 0.3497 - accuracy: 0.8490 - val_loss: 0.3425 - val_accuracy: 0.6562
# 1/1 [==============================] - 0s 263ms/step - loss: 0.2748 - accuracy: 0.9375
#
#
#
# Experiment_5
#
# kernel size           (5, 5)
# strides               (1, 1)
# pool size             (2, 2)
# learning rate           0.01
# optimizer               Adam
# brightness (delta)       0.3
# contrast factor            3
# flip on train            yes
# Name: Experiment_5, dtype: object
#
# Epoch 1/10
# 6/6 [==============================] - 69s 12s/step - loss: 312.5240 - accuracy: 0.5000 - val_loss: 8.6006 - val_accuracy: 0.5312
# Epoch 2/10
# 6/6 [==============================] - 32s 6s/step - loss: 5.1507 - accuracy: 0.5417 - val_loss: 0.7127 - val_accuracy: 0.4688
# Epoch 3/10
# 6/6 [==============================] - 20s 3s/step - loss: 0.6599 - accuracy: 0.5781 - val_loss: 0.4810 - val_accuracy: 0.6562
# Epoch 4/10
# 6/6 [==============================] - 19s 3s/step - loss: 0.5353 - accuracy: 0.7396 - val_loss: 0.4008 - val_accuracy: 0.6875
# Epoch 5/10
# 6/6 [==============================] - 18s 3s/step - loss: 0.4840 - accuracy: 0.6719 - val_loss: 0.3416 - val_accuracy: 0.6875
# Epoch 6/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.4683 - accuracy: 0.7188 - val_loss: 0.3231 - val_accuracy: 0.6875
# Epoch 7/10
# 6/6 [==============================] - 19s 3s/step - loss: 0.4831 - accuracy: 0.7656 - val_loss: 0.3264 - val_accuracy: 0.6875
# Epoch 8/10
# 6/6 [==============================] - 21s 4s/step - loss: 0.4455 - accuracy: 0.7552 - val_loss: 0.3567 - val_accuracy: 0.6562
# Epoch 9/10
# 6/6 [==============================] - 19s 3s/step - loss: 0.3660 - accuracy: 0.7917 - val_loss: 0.3194 - val_accuracy: 0.6562
# Epoch 10/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.5284 - accuracy: 0.8021 - val_loss: 32.4552 - val_accuracy: 0.3750
# 1/1 [==============================] - 0s 476ms/step - loss: 27.3848 - accuracy: 0.6250
#
#
#
# Experiment_6
#
# kernel size           (5, 5)
# strides               (1, 1)
# pool size             (2, 2)
# learning rate          0.001
# optimizer                SGD
# brightness (delta)       0.3
# contrast factor            3
# flip on train            yes
# Name: Experiment_6, dtype: object
#
# Epoch 1/10
# 6/6 [==============================] - 15s 2s/step - loss: 0.7074 - accuracy: 0.5260 - val_loss: 0.6873 - val_accuracy: 0.4688
# Epoch 2/10
# 6/6 [==============================] - 11s 2s/step - loss: 0.6656 - accuracy: 0.5469 - val_loss: 0.6505 - val_accuracy: 0.4688
# Epoch 3/10
# 6/6 [==============================] - 12s 2s/step - loss: 0.6446 - accuracy: 0.5417 - val_loss: 0.6439 - val_accuracy: 0.4688
# Epoch 4/10
# 6/6 [==============================] - 12s 2s/step - loss: 0.6108 - accuracy: 0.5729 - val_loss: 0.6360 - val_accuracy: 0.4688
# Epoch 5/10
# 6/6 [==============================] - 12s 2s/step - loss: 0.5940 - accuracy: 0.6198 - val_loss: 0.6109 - val_accuracy: 0.4688
# Epoch 6/10
# 6/6 [==============================] - 11s 2s/step - loss: 0.5839 - accuracy: 0.5938 - val_loss: 0.5960 - val_accuracy: 0.4688
# Epoch 7/10
# 6/6 [==============================] - 11s 2s/step - loss: 0.5846 - accuracy: 0.5990 - val_loss: 0.5844 - val_accuracy: 0.4688
# Epoch 8/10
# 6/6 [==============================] - 11s 2s/step - loss: 0.5630 - accuracy: 0.6198 - val_loss: 0.5710 - val_accuracy: 0.4688
# Epoch 9/10
# 6/6 [==============================] - 12s 2s/step - loss: 0.5437 - accuracy: 0.6562 - val_loss: 0.5582 - val_accuracy: 0.6250
# Epoch 10/10
# 6/6 [==============================] - 12s 2s/step - loss: 0.5518 - accuracy: 0.6562 - val_loss: 0.5597 - val_accuracy: 0.4688
# 1/1 [==============================] - 1s 605ms/step - loss: 0.5366 - accuracy: 0.4688
#
#
#
# Experiment_7
#
# kernel size           (5, 5)
# strides               (1, 1)
# pool size             (2, 2)
# learning rate          0.001
# optimizer               Adam
# brightness (delta)       0.1
# contrast factor            3
# flip on train            yes
# Name: Experiment_7, dtype: object
#
# Epoch 1/10
# 6/6 [==============================] - 635s 39s/step - loss: 5.3895 - accuracy: 0.6094 - val_loss: 0.8400 - val_accuracy: 0.4688
# Epoch 2/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.8744 - accuracy: 0.7240 - val_loss: 0.4294 - val_accuracy: 0.6562
# Epoch 3/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.4398 - accuracy: 0.7656 - val_loss: 0.3552 - val_accuracy: 0.6875
# Epoch 4/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.4075 - accuracy: 0.7917 - val_loss: 0.3403 - val_accuracy: 0.6562
# Epoch 5/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3916 - accuracy: 0.7760 - val_loss: 0.3405 - val_accuracy: 0.6562
# Epoch 6/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3334 - accuracy: 0.8229 - val_loss: 0.3218 - val_accuracy: 0.6875
# Epoch 7/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3040 - accuracy: 0.8594 - val_loss: 0.3054 - val_accuracy: 0.6875
# Epoch 8/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.2458 - accuracy: 0.8542 - val_loss: 0.2362 - val_accuracy: 0.7812
# Epoch 9/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.2078 - accuracy: 0.9062 - val_loss: 0.3327 - val_accuracy: 0.6875
# Epoch 10/10
# 6/6 [==============================] - 18s 3s/step - loss: 0.1765 - accuracy: 0.9375 - val_loss: 0.2796 - val_accuracy: 0.7188
# 1/1 [==============================] - 1s 780ms/step - loss: 0.3562 - accuracy: 0.8750
#
#
#
# Experiment_8
#
# kernel size           (5, 5)
# strides               (1, 1)
# pool size             (2, 2)
# learning rate          0.001
# optimizer               Adam
# brightness (delta)       0.3
# contrast factor            2
# flip on train            yes
# Name: Experiment_8, dtype: object
#
# Epoch 1/10
# 6/6 [==============================] - 19s 3s/step - loss: 2.5825 - accuracy: 0.6146 - val_loss: 0.3323 - val_accuracy: 0.7500
# Epoch 2/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.4945 - accuracy: 0.7812 - val_loss: 0.3834 - val_accuracy: 0.6875
# Epoch 3/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.4051 - accuracy: 0.7969 - val_loss: 0.2940 - val_accuracy: 0.7188
# Epoch 4/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3854 - accuracy: 0.8073 - val_loss: 0.3009 - val_accuracy: 0.7188
# Epoch 5/10
# 6/6 [==============================] - 18s 3s/step - loss: 0.3495 - accuracy: 0.7917 - val_loss: 0.3262 - val_accuracy: 0.6875
# Epoch 6/10
# 6/6 [==============================] - 18s 3s/step - loss: 0.3052 - accuracy: 0.8594 - val_loss: 0.3113 - val_accuracy: 0.6875
# Epoch 7/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3211 - accuracy: 0.8594 - val_loss: 0.3994 - val_accuracy: 0.6250
# Epoch 8/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.2771 - accuracy: 0.8958 - val_loss: 0.2849 - val_accuracy: 0.8438
# Epoch 9/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.2563 - accuracy: 0.8698 - val_loss: 0.3208 - val_accuracy: 0.9375
# Epoch 10/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.2722 - accuracy: 0.8438 - val_loss: 0.2902 - val_accuracy: 0.6875
# 1/1 [==============================] - 0s 459ms/step - loss: 0.3447 - accuracy: 0.8750
#
#
#
# Experiment_9
#
# kernel size           (5, 5)
# strides               (1, 1)
# pool size             (2, 2)
# learning rate          0.001
# optimizer               Adam
# brightness (delta)       0.3
# contrast factor            3
# flip on train             no
# Name: Experiment_9, dtype: object
#
# Epoch 1/10
# 6/6 [==============================] - 20s 3s/step - loss: 8.6580 - accuracy: 0.5521 - val_loss: 0.3555 - val_accuracy: 0.6875
# Epoch 2/10
# 6/6 [==============================] - 18s 3s/step - loss: 0.6232 - accuracy: 0.7448 - val_loss: 0.4126 - val_accuracy: 0.6875
# Epoch 3/10
# 6/6 [==============================] - 19s 3s/step - loss: 0.4551 - accuracy: 0.7656 - val_loss: 0.3832 - val_accuracy: 0.7188
# Epoch 4/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.3785 - accuracy: 0.8177 - val_loss: 0.3478 - val_accuracy: 0.7812
# Epoch 5/10
# 6/6 [==============================] - 19s 3s/step - loss: 0.3579 - accuracy: 0.8438 - val_loss: 0.3784 - val_accuracy: 0.6875
# Epoch 6/10
# 6/6 [==============================] - 18s 3s/step - loss: 0.2995 - accuracy: 0.8333 - val_loss: 0.3273 - val_accuracy: 0.7812
# Epoch 7/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.2841 - accuracy: 0.8750 - val_loss: 0.3541 - val_accuracy: 0.7500
# Epoch 8/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.2504 - accuracy: 0.9167 - val_loss: 0.3699 - val_accuracy: 0.7500
# Epoch 9/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.1994 - accuracy: 0.9375 - val_loss: 0.4369 - val_accuracy: 0.7500
# Epoch 10/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.1925 - accuracy: 0.9219 - val_loss: 0.3926 - val_accuracy: 0.6875
# 1/1 [==============================] - 0s 462ms/step - loss: 0.3380 - accuracy: 0.8750

# %% [markdown]
# ### WRITTEN ANSWER

# %%
experiments_df.loc[:, 'kernel size':'Validation accuracy']
# Out:
#              kernel size strides pool size  learning rate optimizer  \
# Experiment_1      (5, 5)  (1, 1)    (2, 2)          0.001      Adam
# Experiment_2      (3, 3)  (1, 1)    (2, 2)          0.001      Adam
# Experiment_3      (5, 5)  (2, 2)    (2, 2)          0.001      Adam
# Experiment_4      (5, 5)  (1, 1)    (3, 3)          0.001      Adam
# Experiment_5      (5, 5)  (1, 1)    (2, 2)          0.010      Adam
# Experiment_6      (5, 5)  (1, 1)    (2, 2)          0.001       SGD
# Experiment_7      (5, 5)  (1, 1)    (2, 2)          0.001      Adam
# Experiment_8      (5, 5)  (1, 1)    (2, 2)          0.001      Adam
# Experiment_9      (5, 5)  (1, 1)    (2, 2)          0.001      Adam
#
#               brightness (delta)  contrast factor flip on train  \
# Experiment_1                 0.3                3           yes
# Experiment_2                 0.3                3           yes
# Experiment_3                 0.3                3           yes
# Experiment_4                 0.3                3           yes
# Experiment_5                 0.3                3           yes
# Experiment_6                 0.3                3           yes
# Experiment_7                 0.1                3           yes
# Experiment_8                 0.3                2           yes
# Experiment_9                 0.3                3            no
#
#               Training accuracy  Validation accuracy
# Experiment_1           0.937500              0.75000
# Experiment_2           0.937500              0.75000
# Experiment_3           0.921875              0.68750
# Experiment_4           0.848958              0.65625
# Experiment_5           0.802083              0.37500
# Experiment_6           0.656250              0.46875
# Experiment_7           0.937500              0.71875
# Experiment_8           0.843750              0.68750
# Experiment_9           0.921875              0.68750

# %% [markdown]
# Based on this last table, Experiment 1 and Experiment 2 have the highest Training and Validation accuracies, so I think we could choose any of these two, although I think that in terms of efficiency **I would prefer Experiment 2 with kernel size of (3,3)**.
#
# Mainly because you’d achieve the same accuracies with less trainable parameters (since convolution filters are smaller), and you might diminish the risk of overfitting. For this specific experiment the **test accuracy is 90.62%**.
#
# *NOTE: Even when there are other experiments with higher or equal test accuracies (like Experiment 4), I think we should still choose Experiment 2, since our decision should be blind to the testing dataset.*

# %% [markdown]
# ---
